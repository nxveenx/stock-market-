# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df=pd.read_csv("^NSEI.csv",parse_dates=["Date"])
df
# Out:
#           Date          Open          High           Low         Close  \
# 0   2022-11-07  18211.750000  18255.500000  18064.750000  18202.800781
# 1   2022-11-09  18288.250000  18296.400391  18117.500000  18157.000000
# 2   2022-11-10  18044.349609  18103.099609  17969.400391  18028.199219
# 3   2022-11-11  18272.349609  18362.300781  18259.349609  18349.699219
# 4   2022-11-14  18376.400391  18399.449219  18311.400391  18329.150391
# ..         ...           ...           ...           ...           ...
# 242 2023-10-30  19053.400391  19158.500000  18940.000000  19140.900391
# 243 2023-10-31  19232.949219  19233.699219  19056.449219  19079.599609
# 244 2023-11-01  19064.050781  19096.050781  18973.699219  18989.150391
# 245 2023-11-02  19120.000000  19175.250000  19064.150391  19133.250000
# 246 2023-11-03  19241.000000  19276.250000  19210.900391  19230.599609
#
#         Adj Close  Volume
# 0    18202.800781  314800
# 1    18157.000000  307200
# 2    18028.199219  256500
# ...

# %%
df.describe()
# Out:
#                                 Date          Open          High  \
# count                            247    247.000000    247.000000
# mean   2023-05-05 22:20:53.441295616  18593.583802  18655.417526
# min              2022-11-07 00:00:00  16977.300781  17061.750000
# 25%              2023-02-02 12:00:00  17937.325196  18040.825196
# 50%              2023-05-09 00:00:00  18435.150391  18534.900391
# 75%              2023-08-03 12:00:00  19424.950195  19468.950195
# max              2023-11-03 00:00:00  20156.449219  20222.449219
# std                              NaN    828.052784    824.260614
#
#                 Low         Close     Adj Close         Volume
# count    247.000000    247.000000    247.000000     247.000000
# mean   18500.145290  18579.889937  18579.889937  257301.214575
# min    16828.349609  16945.050781  16945.050781       0.000000
# 25%    17821.375000  17914.600586  17914.600586  217650.000000
# 50%    18365.599609  18496.599609  18496.599609  246400.000000
# ...

# %% [markdown]
# we are gonna analyse the opening,closing price and volume of the nifty50 stock

# %%
row_count=len(df)
print(row_count)
# Below we can see we got 247 days of data from ()
# Out:
# 247

# %%
df["Open"].plot(label="NIFTY50 open price",figsize=(15,7))
df["Close"].plot(label="nifty50 close price")
plt.legend()
plt.title("NIFTY50")
plt.xlabel("No of days")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')
