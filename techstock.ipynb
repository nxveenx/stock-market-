# %%
import pandas_datareader.data as web
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
# %matplotlib inline

# %%
ticker_symbol = ['TCS']
start_date= '2022-11-01'
end_date='2023-11-01'
tcs= yf.download(ticker_symbol,start=start_date,end=end_date)
tcs
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2022-11-01  5.33  5.47  4.81   5.10       5.10  1023600
# 2022-11-02  4.87  4.96  4.45   4.49       4.49   804700
# 2022-11-03  4.52  4.75  4.45   4.62       4.62   547300
# 2022-11-04  4.79  4.79  4.30   4.42       4.42   592800
# 2022-11-07  4.43  4.58  4.38   4.57       4.57   477000
# ...          ...   ...   ...    ...        ...      ...
# 2023-10-25  1.99  1.99  1.87   1.87       1.87   429600
# 2023-10-26  1.86  1.89  1.79   1.82       1.82   417900
# 2023-10-27  1.85  1.90  1.81   1.86       1.86   184800
# 2023-10-30  1.86  1.90  1.83   1.84       1.84   234300
# 2023-10-31  1.84  1.90  1.82   1.85       1.85   244100
#
# [251 rows x 6 columns]

# %%
ticker_symbol = ['infy']
start_date= '2022-11-01'
end_date='2023-11-01'
infy= yf.download(ticker_symbol,start=start_date,end=end_date)
infy
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-11-01  19.190001  19.219999  18.840000  18.910000  18.417461   5474700
# 2022-11-02  18.709999  18.879999  18.410000  18.410000  17.930483   6370600
# 2022-11-03  18.200001  18.270000  18.080000  18.190001  17.716215  11328700
# 2022-11-04  18.270000  18.459999  18.100000  18.330000  17.852568  10899800
# 2022-11-07  18.250000  18.660000  18.250000  18.580000  18.096056   6280400
# ...               ...        ...        ...        ...        ...       ...
# 2023-10-25  16.459999  16.530001  16.370001  16.379999  16.379999   4727100
# 2023-10-26  16.389999  16.469999  16.270000  16.320000  16.320000   6991300
# 2023-10-27  16.510000  16.610001  16.400000  16.440001  16.440001   5591700
# 2023-10-30  16.500000  16.559999  16.389999  16.500000  16.500000   5559700
# ...

# %%
tcs["Open"].plot(label='TCS',figsize=(15,7))
infy["Open"].plot(label='infosys')
plt.legend()
plt.title("Tcs and Infosys opening prices")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
tcs['Volume'].plot(label='tcs',figsize=(15,7))
infy['Volume'].plot(label='infosys')
plt.legend()
plt.title("volumes sold by tcs and Infosys")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# total traded

# %%
tcs['Total traded']=tcs['Open']*tcs['Volume']
infy['Total traded']=infy['Open']*infy['Volume']
tcs.head()
# Out:
#             Open  High   Low  Close  Adj Close   Volume  Total traded
# Date
# 2022-11-01  5.33  5.47  4.81   5.10       5.10  1023600  5.455788e+06
# 2022-11-02  4.87  4.96  4.45   4.49       4.49   804700  3.918889e+06
# 2022-11-03  4.52  4.75  4.45   4.62       4.62   547300  2.473796e+06
# 2022-11-04  4.79  4.79  4.30   4.42       4.42   592800  2.839512e+06
# 2022-11-07  4.43  4.58  4.38   4.57       4.57   477000  2.113110e+06

# %%
infy.head()
# Out:
#                  Open       High    Low      Close  Adj Close    Volume  \
# Date
# 2022-11-01  19.190001  19.219999  18.84  18.910000  18.417461   5474700
# 2022-11-02  18.709999  18.879999  18.41  18.410000  17.930483   6370600
# 2022-11-03  18.200001  18.270000  18.08  18.190001  17.716215  11328700
# 2022-11-04  18.270000  18.459999  18.10  18.330000  17.852568  10899800
# 2022-11-07  18.250000  18.660000  18.25  18.580000  18.096056   6280400
#
#             Total traded
# Date
# 2022-11-01  1.050595e+08
# 2022-11-02  1.191939e+08
# 2022-11-03  2.061823e+08
# 2022-11-04  1.991394e+08
# 2022-11-07  1.146173e+08

# %%
tcs['Total traded'].plot(label="tcs",figsize=(15,7))
infy['Total traded'].plot(label='infosys')
plt.legend()
plt.title("Total volumes traded")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
infy['Total traded'].argmax()
# Out:
# 111

# %%
infy.iloc[infy['Total traded'].argmax()]
# Out:
# Open            1.587000e+01
# High            1.597000e+01
# Low             1.533000e+01
# Close           1.540000e+01
# Adj Close       1.499888e+01
# Volume          4.041500e+07
# Total traded    6.413860e+08
# Name: 2023-04-13 00:00:00, dtype: float64

# %% [markdown]
# Moving average

# %%
infy["Open"].plot(figsize=(15,7))
infy['MA 50']=infy['Open'].rolling(50).mean()
infy['MA 50'].plot(label='MA 50')
infy['MA 20']=infy['Open'].rolling(20).mean()
infy['MA 20'].plot(label='MA 30')
plt.legend()

# %%
tcs["Open"].plot(figsize=(15,7))
tcs['MA 50']=tcs['Open'].rolling(50).mean()
tcs['MA 50'].plot()
plt.legend()

# %%
from pandas.plotting import scatter_matrix

# %%
sc=pd.concat([tcs['Open'],infy['Open']], axis=1)
sc.columns= ['TCS OPEN','INFOSYS OPEN']
scatter_matrix(sc,figsize=(8,8),hist_kwds={'bins':50})
# Out:
# array([[<Axes: xlabel='TCS OPEN', ylabel='TCS OPEN'>,
#         <Axes: xlabel='INFOSYS OPEN', ylabel='TCS OPEN'>],
#        [<Axes: xlabel='TCS OPEN', ylabel='INFOSYS OPEN'>,
#         <Axes: xlabel='INFOSYS OPEN', ylabel='INFOSYS OPEN'>]],
#       dtype=object)
